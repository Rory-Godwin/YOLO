# %% [markdown]
# <a href="https://colab.research.google.com/github/Rory-Godwin/YOLO/blob/main/BubbleYolo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/bubbliiiing/yolov4-keras
# Out:
# fatal: destination path 'yolov4-keras' already exists and is not an empty directory.

# %%
# %cd yolov4-keras/
# Out:
# /content/yolov4-keras

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !pip install tensorflow-gpu==1.14
# !pip install keras==2.2.4
# !pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 377.1MB 47kB/s
# ...

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# 'Colab Notebooks'  'My Drive'   yolov4

# %%
# cd back into the yolov4-keras folder to run detections
# %cd yolov4-keras
# Out:
# /content/yolov4-keras

# %%
assert False

# %%
# copy over both datasets into the root directory of the Colab VM (comment out test.zip if you are not using a validation dataset)
# !cp /mydrive/yolov4/JPEGImages.zip ../
# !cp /mydrive/yolov4/Annotations.zip ../
# Out:
# ^C

# %%
# %cd /content/yolov4-keras/
# Out:
# /content/yolov4-keras

# %%
# unzip the datasets and their contents so that they are now in /yolov4-keras/VOCdevkit/VOC2007/ folder
# !unzip ../Annotations.zip -d VOC2007
# !unzip ../JPEGImages.zip -d VOC2007/ #/VOCdevkit/VOC2007/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: VOC2007/Annotations/000041.xml
#   inflating: VOC2007/Annotations/000042.xml
#   inflating: VOC2007/Annotations/000044.xml
#   inflating: VOC2007/Annotations/000046.xml
#   inflating: VOC2007/Annotations/000047.xml
#   inflating: VOC2007/Annotations/000048.xml
#   inflating: VOC2007/Annotations/000050.xml
#   inflating: VOC2007/Annotations/000051.xml
#   inflating: VOC2007/Annotations/000052.xml
#   inflating: VOC2007/Annotations/000060.xml
#   inflating: VOC2007/Annotations/000061.xml
#   inflating: VOC2007/Annotations/000063.xml
#   inflating: VOC2007/Annotations/000064.xml
#   inflating: VOC2007/Annotations/000065.xml
#   inflating: VOC2007/Annotations/000066.xml
#   inflating: VOC2007/Annotations/000072.xml
#   inflating: VOC2007/Annotations/000073.xml
#   inflating: VOC2007/Annotations/000077.xml
#   inflating: VOC2007/Annotations/000078.xml
#   inflating: VOC2007/Annotations/000081.xml
# ...

# %%
# This stops 'Run all' at this cell by causing an error
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-90e9831ca4f5> in <module>()
#       1 # This stops 'Run all' at this cell by causing an error
# ----> 2 assert False
#
# AssertionError:

# %% [markdown]
# In VOC2007
#
#       in Annotations folder
#             delete README.md
#       exit to VOC2007
#
#       in JPEGImages folder
#           delete README.md
#       exit to VOC2007
#
#       delete Annotations folder
#       delete JPEGImages folder

# %% [markdown]
# In yolov4-keras there is a new folder VOC2007
#
#       move Annotations folder to VOCdevkit/VOC2007
#       move JPEGImages folder to VOCdevkit/VOC2007

# %% [markdown]
# Check directory position

# %%
# !ls

# %% [markdown]
# You must be in yolov4-keras to run this correctly.

# %%
#%cd /content/yolov4-keras
#!ls
# !python VOCdevkit/VOC2007/voc2yolo4.py
# Out:
# train and val size 5011
# traub suze 5011

# %%
#%cd ..
#%cd ..
# !ls
# Out:
# Annotations.zip  gdrive  JPEGImages.zip  sample_data  yolov4-keras

# %%
# !python voc_annotation.py

# %%
# upload the custom .cfg back to cloud VM from Google Drive
# !cp /mydrive/yolov4/new_classes.txt ./model_data/

# %%
# upload yolo4_voc_weights.h5 to cloud VM from Google Drive
# !cp /mydrive/yolov4/yolo4_voc_weights.h5 ./model_data/

# %%
# This stops 'Run all' at this cell by causing an error
assert False

# %% [markdown]
# alpha
#
#       at this point open train.py
#       on line 196 change to
#           classes_path = 'model_data/new_classes.txt'
#
#       on line 203 change to
#           weights_path = 'model_data/yolo4_voc_weight.h5'
#
#       close file
#
#       open yolo.py
#       on line 24 change to
#           "model_path"        : 'model_data/yolo4_voc_weights.h5',
#
#       on line 26 change to
#           "classes_path"      : 'model_data/new_classes.txt',
#
#       close file

# %% [markdown]
# To stop auto shut down
# in the brouser terminal (F12)
# go to console
# at the lowest empty cell
# paste the code below and press enter
#
#     function ClickConnect(){
#     console.log("Working");
#     document
#       .querySelector('#top-toolbar > colab-connect-button')
#       .shadowRoot.querySelector('#connect')
#       .click()
#     }
#     setInterval(ClickConnect,60000)
#
#
# this code simlates a mouse click every minute, this is needed as google colab will deavtivate after 30-90 minutes of inactivity, however it is a good idea to keep a eye of the program incase.
#
# then go to start and search power and sleep settings -> When plugged in, turn off after -> set to never
#
# When plugged in, PC goes to sleep after -> never
#
# if you are on a laptop ensure you plug in the power cable
#
# these actions will stop you computer turning off or going to sleep as this will stop the training.
#
# if you close the tab or google the program will also stop.

# %%
# !ls
# %cd yolov4-keras/
# Out:
# Annotations.zip  gdrive  JPEGImages.zip  sample_data  yolov4-keras
# /content/yolov4-keras

# %%
# !python train.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
