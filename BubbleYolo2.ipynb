# %% [markdown]
# <a href="https://colab.research.google.com/github/Rory-Godwin/YOLO/blob/main/BubbleYolo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# YOLOv4 from Bubbliiing github repo yolov4-keras
#
# Created by Rory Godwin
#
# 30/03/2021 15:35
#
#
#             PLEASE SAVE YOUR OWN COPY IN YOU DRIVE BEFORE EDITING!!!
#
#
#
#
#   This is designed for use to train test and modify the YOLOv4 CNN.
#
#   Using this will allow for fast training on a GPU without having to use a high level PC or laptop.
#
#
#   HOW TO USE
#
#     To start with make sure you save a copy to your google drive.
#
#     While in you drive there are a few steps to complete.
#
#           Create a folder called yolov4
#
#           in that folder create called backup
#
#           upload the yolo4_voc_weights.h5 and new_classes.txt
#
#           upload comprressed Annotations and JPEGImages folders

# %%
print ('hi')
# Out:
# hi

# %% [markdown]
# Clone repo

# %%
# !git clone https://github.com/Rory-Godwin/YOLO.git
# Out:
# Cloning into 'YOLO'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 90 (delta 7), reused 84 (delta 7), pack-reused 0
# Unpacking objects: 100% (90/90), done.

# %% [markdown]
# CD to directory location
#
# change as needed

# %%
# %cd yolov4-keras/
# Out:
# [Errno 2] No such file or directory: 'yolov4-keras/'
# /content

# %% [markdown]
# Prep GPU

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %% [markdown]
# Roll back requirements

# %%
# !pip install tensorflow==1.14
# !pip install tensorflow-gpu==1.14
# !pip install keras==2.2.4
# !pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 109.3MB 95kB/s
# ...
#      |████████████████████████████████| 491kB 35.0MB/s
# ...
#      |████████████████████████████████| 3.2MB 38.6MB/s
# ...
#      |████████████████████████████████| 51kB 5.6MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...
#      |████████████████████████████████| 377.1MB 44kB/s
# ...
#      |████████████████████████████████| 317kB 10.7MB/s
# ...
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# ...

# %% [markdown]
# Mount google drive to load files

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Mounted at /content/gdrive

# %% [markdown]
# list items in google drive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# 'Colab Notebooks'  'My Drive'   yolov4

# %% [markdown]
# CD into colab VM
#
# change as needed

# %%
# cd back into the yolov4-keras folder to run detections
# %cd /content/YOLO/
# !ls
# Out:
# /content/YOLO
# 2007_test.txt	   img			  README.md    test.py
# 2007_train.txt	   kmeans_for_anchors.py  sample1.jpg  train.py
# 2007_val.txt	   LICENSE		  sample2.jpg  utils
# BubbleYolo1.ipynb  model_data		  sample3.jpg  video.py
# coco_classes.txt   nets			  sample4.jpg  vision_for_anchors.py
# font		   person1.jpg		  sample5.jpg  voc_annotation.py
# FPS_test.py	   person2.jpg		  sample6.jpg  voc_classes.txt
# get_dr_txt.py	   person3.jpg		  sample7.jpg  VOCdevkit
# get_gt_txt.py	   predict.py		  sample8.jpg  yolo.py
# get_map.py	   __pycache__		  sample9.jpg  常见问题汇总.md

# %% [markdown]
# copy zip data sets to colab VM

# %%
# copy over both datasets into the root directory of the Colab VM (comment out test.zip if you are not using a validation dataset)
# !cp /mydrive/yolov4/JPEGImages.zip ../
# !cp /mydrive/yolov4/Annotations.zip ../

# %%
# !ls
#%cd VOCdevkit/VOC2007/
# Out:
# 2007_test.txt	   img			  README.md    test.py
# 2007_train.txt	   kmeans_for_anchors.py  sample1.jpg  train.py
# 2007_val.txt	   LICENSE		  sample2.jpg  utils
# BubbleYolo1.ipynb  model_data		  sample3.jpg  video.py
# coco_classes.txt   nets			  sample4.jpg  vision_for_anchors.py
# font		   person1.jpg		  sample5.jpg  voc_annotation.py
# FPS_test.py	   person2.jpg		  sample6.jpg  voc_classes.txt
# get_dr_txt.py	   person3.jpg		  sample7.jpg  VOCdevkit
# get_gt_txt.py	   predict.py		  sample8.jpg  yolo.py
# get_map.py	   __pycache__		  sample9.jpg  常见问题汇总.md

# %% [markdown]
# unzip and create VOC2007 folder to save dataset

# %%
# unzip the datasets and their contents so that they are now in /yolov4-keras/VOCdevkit/VOC2007/ folder
# !ls

# !unzip ../Annotations.zip -d VOC2007/
# !unzip ../JPEGImages.zip -d VOC2007/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: VOC2007/JPEGImages/000030.jpg
#   inflating: VOC2007/JPEGImages/000032.jpg
#   inflating: VOC2007/JPEGImages/000033.jpg
#   inflating: VOC2007/JPEGImages/000034.jpg
#   inflating: VOC2007/JPEGImages/000035.jpg
#   inflating: VOC2007/JPEGImages/000036.jpg
#   inflating: VOC2007/JPEGImages/000039.jpg
#   inflating: VOC2007/JPEGImages/000041.jpg
#   inflating: VOC2007/JPEGImages/000042.jpg
#   inflating: VOC2007/JPEGImages/000044.jpg
#   inflating: VOC2007/JPEGImages/000046.jpg
#   inflating: VOC2007/JPEGImages/000047.jpg
#   inflating: VOC2007/JPEGImages/000048.jpg
#   inflating: VOC2007/JPEGImages/000050.jpg
#   inflating: VOC2007/JPEGImages/000051.jpg
#   inflating: VOC2007/JPEGImages/000052.jpg
#   inflating: VOC2007/JPEGImages/000060.jpg
#   inflating: VOC2007/JPEGImages/000061.jpg
#   inflating: VOC2007/JPEGImages/000063.jpg
#   inflating: VOC2007/JPEGImages/000064.jpg
#   inflating: VOC2007/JPEGImages/000065.jpg
# ...

# %% [markdown]
# Stop Run All

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-a871fdc9ebee> in <module>()
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# Move Annotations and JPEGImages folders into /VOCdevkit/VOC2007/

# %% [markdown]
# Check directory position

# %%
# !ls
# Out:
# 2007_test.txt	   kmeans_for_anchors.py  sample2.jpg  video.py
# 2007_train.txt	   LICENSE		  sample3.jpg  vision_for_anchors.py
# 2007_val.txt	   model_data		  sample4.jpg  VOC2007
# BubbleYolo1.ipynb  nets			  sample5.jpg  voc_annotation.py
# coco_classes.txt   person1.jpg		  sample6.jpg  voc_classes.txt
# font		   person2.jpg		  sample7.jpg  VOCdevkit
# FPS_test.py	   person3.jpg		  sample8.jpg  yolo.py
# get_dr_txt.py	   predict.py		  sample9.jpg  常见问题汇总.md
# get_gt_txt.py	   __pycache__		  test.py
# get_map.py	   README.md		  train.py
# img		   sample1.jpg		  utils

# %% [markdown]
# Run voc2yolo4.py script

# %%
#%cd /content/yolov4-keras
# !ls
# !python VOCdevkit/VOC2007/voc2yolo4.py
# Out:
# 2007_test.txt	   kmeans_for_anchors.py  sample2.jpg  video.py
# 2007_train.txt	   LICENSE		  sample3.jpg  vision_for_anchors.py
# 2007_val.txt	   model_data		  sample4.jpg  VOC2007
# BubbleYolo1.ipynb  nets			  sample5.jpg  voc_annotation.py
# coco_classes.txt   person1.jpg		  sample6.jpg  voc_classes.txt
# font		   person2.jpg		  sample7.jpg  VOCdevkit
# FPS_test.py	   person3.jpg		  sample8.jpg  yolo.py
# get_dr_txt.py	   predict.py		  sample9.jpg  常见问题汇总.md
# get_gt_txt.py	   __pycache__		  test.py
# get_map.py	   README.md		  train.py
# img		   sample1.jpg		  utils
# train and val size 5011
# traub suze 5011

# %% [markdown]
# Run voc_annotation.py script

# %%
# !python voc_annotation.py

# %% [markdown]
# Copy new_classes.txt to colab VM

# %%
# upload the custom .cfg back to cloud VM from Google Drive
# !cp /mydrive/yolov4/new_classes.txt ./model_data/

# %% [markdown]
# Copy yolo4_voc_weights.h5 to colab VM

# %%
# upload the custom .cfg back to cloud VM from Google Drive
# !cp /mydrive/yolov4/yolo4_voc_weights.h5 ./model_data/

# %% [markdown]
# To stop auto shut down
# in the brouser terminal (F12)
# go to console
# at the lowest empty cell
# paste the code below and press enter
#
#     function ClickConnect(){
#     console.log("Working");
#     document
#       .querySelector('#top-toolbar > colab-connect-button')
#       .shadowRoot.querySelector('#connect')
#       .click()
#     }
#     setInterval(ClickConnect,60000)
#
#
# this code simlates a mouse click every minute, this is needed as google colab will deavtivate after 30-90 minutes of inactivity, however it is a good idea to keep a eye of the program incase.
#
# then go to start and search power and sleep settings -> When plugged in, turn off after -> set to never
#
# When plugged in, PC goes to sleep after -> never
#
# if you are on a laptop ensure you plug in the power cable
#
# these actions will stop you computer turning off or going to sleep as this will stop the training.
#
# if you close the tab or google the program will also stop.

# %% [markdown]
# google colab runs to 11 epochs with console hack and may still crash that is 11epochs 10 minutes per epoch stop run at 110 minuets and save files to drive

# %%
# %cd yolov4-keras/
# !python train.py
# !cp logs/ /mydrive/yolov4/backup/
# Out:
# [Errno 2] No such file or directory: 'yolov4-keras/'
# /content/YOLO
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
